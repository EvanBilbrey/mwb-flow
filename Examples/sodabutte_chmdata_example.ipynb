# %%
import os
from pathlib import Path
import geopandas as gpd
import xarray as xr
from shapely.geometry import Polygon, Point
import numpy as np
import datetime

chmdata_dir = r'C:\Users\CND905\Downloaded_Programs\chmdata\src'
os.chdir(chmdata_dir)
from chmdata.query import get_usgs_gauge_data

# %%
data = get_usgs_gauge_data(sites=['06187915'], dataset='00060', timestep='iv', start='2020-10-01', end='2024-09-30')

data = data['00060'].resample(time='D').mean()
data = data.rename('discharge')

data
# Out:
# <xarray.DataArray 'discharge' (time: 1461, location: 1)>
# array([[ 8.72833333],
#        [ 8.57760417],
#        [ 8.46197917],
#        ...,
#        [18.57083333],
#        [17.840625  ],
#        [17.11666667]])
# Coordinates:
#   * location  (location) <U8 '06187915'
#   * time      (time) datetime64[ns] 2020-10-01 2020-10-02 ... 2024-09-30

# %%
dir = r'C:\Users\CND905\Downloaded_Programs\mwb_flow\Examples'
os.chdir(dir)

data.to_netcdf('sodabutte_chumdata_discharge.nc')
